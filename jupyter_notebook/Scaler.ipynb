# %%
import numpy as np
from sklearn import datasets

# %%
iris=datasets.load_iris()

# %%
X=iris.data
y=iris.target

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(iris.data,iris.target,test_size=0.2,random_state=233)

# %%
X_test.shape
# Out:
# (30, 4)

# %% [markdown]
# #### scikit-learn中的StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
standardScaler=StandardScaler()

# %%
standardScaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
standardScaler.mean_
# Out:
# array([5.86916667, 3.065     , 3.75916667, 1.19083333])

# %%
standardScaler.scale_
# Out:
# array([0.8416052 , 0.45417508, 1.78789895, 0.76267029])

# %%
X_train=standardScaler.transform(X_train)

# %%
X_test_standard=standardScaler.transform(X_test)

# %%
X_test_standard
# Out:
# array([[-0.79510758, -0.80365484,  0.0787703 ,  0.27425569],
#        [ 1.10602137,  0.2972422 ,  1.19740175,  1.45432001],
#        [ 0.27427746, -0.14311662,  0.47029131,  0.27425569],
#        [ 1.46248305, -0.14311662,  1.19740175,  1.1920835 ],
#        [-1.15156925,  0.07706279, -1.26358745, -1.29916341],
#        [-1.15156925, -1.46419307, -0.25681914, -0.25021734],
#        [ 0.27427746, -0.58347543,  0.52622288,  0.01201917],
#        [-0.55746646,  1.83849807, -1.37545059, -1.03692689],
#        [ 0.03663634, -0.14311662,  0.24656502,  0.40537395],
#        [-0.31982534, -0.14311662,  0.19063344,  0.14313743],
#        [ 0.1554569 , -0.36329603,  0.41435974,  0.40537395],
#        [ 1.22484193,  0.07706279,  0.63808603,  0.40537395],
#        [ 0.1554569 , -1.90455189,  0.6940176 ,  0.40537395],
#        [-0.31982534, -0.14311662,  0.41435974,  0.40537395],
#        [-0.91392813,  0.51742161, -1.1517243 , -0.90580863],
#        [-1.50803093,  0.07706279, -1.26358745, -1.29916341],
#        [-1.50803093,  0.73760102, -1.31951902, -1.16804515],
#        [ 0.74955969, -0.14311662,  0.80588074,  1.06096524],
#        [ 0.74955969, -0.14311662,  0.97367546,  0.79872872],
#        [-1.15156925,  1.17795984, -1.31951902, -1.43028167],
#        [ 0.51191858,  0.51742161,  1.25333333,  1.71655653],
#        [ 0.98720081,  0.07706279,  1.02960704,  1.58543827],
#        [ 0.98720081,  0.07706279,  0.35842816,  0.27425569],
#        [ 0.39309802, -0.58347543,  0.58215445,  0.79872872],
#        [-1.38921037,  0.2972422 , -1.20765588, -1.29916341],
#        [-1.03274869, -0.14311662, -1.20765588, -1.29916341],
#        [-1.50803093,  1.17795984, -1.54324531, -1.29916341],
#        [-0.08218422, -1.02383425,  0.13470187,  0.01201917],
#        [-0.08218422, -0.58347543,  0.74994917,  1.58543827],
#        [-0.20100478, -1.02383425, -0.14495599, -0.25021734]])

# %%
X_train
# Out:
# array([[-1.27038981, -0.14311662, -1.31951902, -1.16804515],
#        [ 0.51191858,  0.51742161,  0.52622288,  0.53649221],
#        [ 0.27427746, -0.58347543,  0.13470187,  0.14313743],
#        [-1.03274869, -2.34491071, -0.14495599, -0.25021734],
#        [-0.31982534, -0.80365484,  0.24656502,  0.14313743],
#        [-0.55746646,  1.39813925, -1.26358745, -1.29916341],
#        [ 0.98720081, -1.24401366,  1.14147018,  0.79872872],
#        [-1.03274869, -1.68437248, -0.25681914, -0.25021734],
#        [ 1.70012417, -0.36329603,  1.42112805,  0.79872872],
#        [ 2.05658585, -0.14311662,  1.58892276,  1.1920835 ],
#        [ 0.51191858, -0.80365484,  0.63808603,  0.79872872],
#        [-1.03274869,  0.51742161, -1.31951902, -1.29916341],
#        [-0.08218422, -0.80365484,  0.0787703 ,  0.01201917],
#        [ 2.1754064 , -1.02383425,  1.75671748,  1.45432001],
#        [-1.15156925,  0.07706279, -1.26358745, -1.43028167],
#        [ 0.27427746, -0.36329603,  0.52622288,  0.27425569],
#        [-0.55746646,  0.73760102, -1.1517243 , -1.29916341],
#        [ 0.63073914, -0.58347543,  1.02960704,  1.1920835 ],
#        [-0.91392813,  1.61831866, -1.26358745, -1.16804515],
#        [ 1.10602137, -0.14311662,  0.97367546,  1.1920835 ],
#        [-0.08218422,  2.05867748, -1.43138217, -1.29916341],
#        [ 0.27427746, -1.02383425,  1.02960704,  0.27425569],
#        [ 0.51191858, -1.24401366,  0.6940176 ,  0.92984698],
#        [ 0.51191858, -1.24401366,  0.63808603,  0.40537395],
#        [ 0.03663634,  0.2972422 ,  0.58215445,  0.79872872],
#        [ 2.1754064 , -0.14311662,  1.3092649 ,  1.45432001],
#        [ 0.98720081,  0.51742161,  1.08553861,  1.1920835 ],
#        [ 1.34366249,  0.2972422 ,  0.52622288,  0.27425569],
#        [ 1.22484193,  0.07706279,  0.91774389,  1.1920835 ],
#        [ 0.1554569 , -0.14311662,  0.58215445,  0.79872872],
#        [-0.55746646,  1.83849807, -1.1517243 , -1.03692689],
#        [-1.03274869,  0.95778043, -1.20765588, -0.77469037],
#        [-1.27038981, -0.14311662, -1.31951902, -1.43028167],
#        [ 1.58130361,  0.2972422 ,  1.25333333,  0.79872872],
#        [-1.03274869,  0.73760102, -1.26358745, -1.29916341],
#        [ 0.1554569 , -1.90455189,  0.13470187, -0.25021734],
#        [ 0.39309802, -1.90455189,  0.41435974,  0.40537395],
#        [-0.91392813,  0.95778043, -1.31951902, -1.29916341],
#        [ 1.58130361, -0.14311662,  1.14147018,  0.53649221],
#        [-0.31982534, -0.58347543,  0.63808603,  1.06096524],
#        [ 0.74955969, -0.58347543,  0.47029131,  0.40537395],
#        [ 1.58130361,  1.17795984,  1.3092649 ,  1.71655653],
#        [-1.27038981,  0.73760102, -1.20765588, -1.29916341],
#        [ 0.51191858, -0.36329603,  1.02960704,  0.79872872],
#        [ 2.1754064 ,  1.61831866,  1.64485434,  1.32320175],
#        [-0.08218422, -0.80365484,  0.19063344, -0.25021734],
#        [-1.15156925, -1.24401366,  0.41435974,  0.66761046],
#        [-0.4386459 , -1.24401366,  0.13470187,  0.14313743],
#        [ 1.22484193,  0.2972422 ,  1.08553861,  1.45432001],
#        [-1.50803093,  0.2972422 , -1.31951902, -1.29916341],
#        [ 0.39309802, -0.36329603,  0.30249659,  0.14313743],
#        [-0.20100478,  2.93939511, -1.26358745, -1.03692689],
#        [ 0.86838025, -0.36329603,  0.47029131,  0.14313743],
#        [ 0.98720081,  0.07706279,  0.52622288,  0.40537395],
#        [ 0.39309802,  0.73760102,  0.91774389,  1.45432001],
#        [-0.20100478, -0.58347543,  0.19063344,  0.14313743],
#        [-1.03274869,  0.95778043, -1.37545059, -1.16804515],
#        [ 0.63073914,  0.2972422 ,  0.41435974,  0.40537395],
#        [-0.4386459 , -1.46419307, -0.03309285, -0.25021734],
#        [ 0.51191858, -1.68437248,  0.35842816,  0.14313743],
#        [ 1.22484193,  0.07706279,  0.74994917,  1.45432001],
#        [ 0.63073914, -0.80365484,  0.86181232,  0.92984698],
#        [ 0.51191858,  0.73760102,  1.02960704,  1.58543827],
#        [-1.74567205,  0.2972422 , -1.37545059, -1.29916341],
#        [-0.20100478, -0.14311662,  0.24656502,  0.01201917],
#        [-0.31982534, -1.24401366,  0.0787703 , -0.11909908],
#        [-0.08218422, -0.80365484,  0.74994917,  0.92984698],
#        [-0.79510758,  0.95778043, -1.26358745, -1.29916341],
#        [ 0.51191858, -0.58347543,  0.74994917,  0.40537395],
#        [ 0.63073914,  0.07706279,  0.97367546,  0.79872872],
#        [-0.67628702,  1.39813925, -1.26358745, -1.29916341],
#        [-0.91392813,  0.95778043, -1.31951902, -1.16804515],
#        [-1.38921037,  0.2972422 , -1.37545059, -1.29916341],
#        [-1.03274869,  1.17795984, -1.31951902, -1.29916341],
#        [-1.27038981,  0.73760102, -1.03986116, -1.29916341],
#        [-0.31982534, -0.36329603, -0.08902442,  0.14313743],
#        [-1.86449261, -0.14311662, -1.48731374, -1.43028167],
#        [ 0.63073914, -0.58347543,  1.02960704,  1.32320175],
#        [-0.4386459 , -1.46419307,  0.02283873, -0.11909908],
#        [ 0.63073914, -0.36329603,  0.30249659,  0.14313743],
#        [-1.74567205, -0.36329603, -1.31951902, -1.29916341],
#        [ 0.03663634, -0.14311662,  0.74994917,  0.79872872],
#        [-0.08218422, -0.80365484,  0.74994917,  0.92984698],
#        [ 0.27427746, -0.14311662,  0.63808603,  0.79872872],
#        [ 0.98720081, -0.14311662,  0.80588074,  1.45432001],
#        [-0.55746646,  0.73760102, -1.26358745, -1.03692689],
#        [-0.79510758,  2.27885689, -1.26358745, -1.43028167],
#        [-1.27038981,  0.07706279, -1.20765588, -1.29916341],
#        [-1.74567205, -0.14311662, -1.37545059, -1.29916341],
#        [-0.91392813,  1.61831866, -1.20765588, -1.29916341],
#        [ 2.1754064 , -0.58347543,  1.64485434,  1.06096524],
#        [ 0.98720081,  0.51742161,  1.08553861,  1.71655653],
#        [ 0.1554569 , -0.80365484,  0.74994917,  0.53649221],
#        [-0.91392813,  1.39813925, -1.26358745, -1.03692689],
#        [-0.79510758,  0.73760102, -1.31951902, -1.29916341],
#        [-0.4386459 ,  2.49903629, -1.31951902, -1.29916341],
#        [ 1.10602137, -0.58347543,  0.58215445,  0.27425569],
#        [ 0.86838025, -0.14311662,  0.35842816,  0.27425569],
#        [ 0.63073914,  0.2972422 ,  0.86181232,  1.45432001],
#        [-0.20100478, -0.58347543,  0.41435974,  0.14313743],
#        [ 0.98720081, -0.14311662,  0.6940176 ,  0.66761046],
#        [ 0.74955969,  0.2972422 ,  0.74994917,  1.06096524],
#        [-1.62685149, -1.68437248, -1.37545059, -1.16804515],
#        [-0.91392813,  1.61831866, -1.03986116, -1.03692689],
#        [ 1.81894473, -0.58347543,  1.3092649 ,  0.92984698],
#        [-0.4386459 ,  0.95778043, -1.37545059, -1.29916341],
#        [ 0.74955969, -0.14311662,  1.14147018,  1.32320175],
#        [-1.03274869,  0.73760102, -1.20765588, -1.03692689],
#        [-0.4386459 , -1.68437248,  0.13470187,  0.14313743],
#        [-0.55746646, -0.14311662,  0.41435974,  0.40537395],
#        [-0.20100478,  1.61831866, -1.1517243 , -1.16804515],
#        [-1.15156925, -0.14311662, -1.31951902, -1.29916341],
#        [-0.20100478, -0.36329603,  0.24656502,  0.14313743],
#        [-0.4386459 , -1.02383425,  0.35842816,  0.01201917],
#        [-0.91392813, -1.24401366, -0.42461386, -0.11909908],
#        [-1.03274869,  0.2972422 , -1.43138217, -1.29916341],
#        [ 0.1554569 ,  0.73760102,  0.41435974,  0.53649221],
#        [ 2.41304752,  1.61831866,  1.47705962,  1.06096524],
#        [-0.20100478, -1.24401366,  0.6940176 ,  1.06096524],
#        [-0.91392813,  0.73760102, -1.26358745, -1.29916341]])

# %% [markdown]
# #### 开始使用KNN预测

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_clf=KNeighborsClassifier(n_neighbors=3)

# %%
knn_clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
knn_clf.score(X_test_standard,y_test)
# Out:
# 0.9666666666666667
